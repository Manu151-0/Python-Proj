# %% [markdown]
# # Python Web Scraping Project Using Beautiful Soup

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import random
import os

# %%
urls = {
    'Towards Data Science': 'https://towardsdatascience.com/archive/{0}/{1:02d}/{2:02d}',
    'UX Collective': 'https://uxdesign.cc/archive/{0}/{1:02d}/{2:02d}',
    'The Startup': 'https://medium.com/swlh/archive/{0}/{1:02d}/{2:02d}',
    'The Writing Cooperative': 'https://writingcooperative.com/archive/{0}/{1:02d}/{2:02d}',
    'Data Driven Investor': 'https://medium.com/datadriveninvestor/archive/{0}/{1:02d}/{2:02d}',
    'Better Humans': 'https://medium.com/better-humans/archive/{0}/{1:02d}/{2:02d}',
    'Better Marketing': 'https://medium.com/better-marketing/archive/{0}/{1:02d}/{2:02d}',
}

# %%
def is_leap(year):
    if year % 4 != 0:
        return False
    elif year % 100 != 0:
        return True
    elif year % 400 != 0:
        return False
    else:
        return True
    
def convert_day(day, year):
    month_days = [31, 29 if is_leap(year) else 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
    m = 0
    d = 0
    while day > 0:
        d = day
        day -= month_days[m]
        m += 1
    return (m, d)

def get_claps(claps_str):
    if (claps_str is None) or (claps_str == '') or (claps_str.split is None):
        return 0
    split = claps_str.split('K')
    claps = float(split[0])
    claps = int(claps*1000) if len(split) == 2 else int(claps)
    return claps

def get_img(img_url, dest_folder, dest_filename):
    ext = img_url.split('.')[-1]
    if len(ext) > 4:
        ext = 'jpg'
    dest_filename = f'{dest_filename}.{ext}'
    with open(f'{dest_folder}/{dest_filename}', 'wb') as f:
        f.write(requests.get(img_url, allow_redirects=False).content)
    return dest_filename

# %%
year = 2019
selected_days = random.sample([i for i in range(1, 367 if is_leap(year) else 366)], 50)

# %%
img_dir = 'images'
if not os.path.exists(img_dir):
    os.mkdir(img_dir)

# %%
data = []
article_id = 0
i = 0
n = len(selected_days)
for d in selected_days:
    i += 1
    month, day = convert_day(d, year)
    date = '{0}-{1:02d}-{2:02d}'.format(year, month, day)
    print(f'{i} / {n} ; {date}')
    for publication, url in urls.items():
        response = requests.get(url.format(year, month, day), allow_redirects=True)
        if not response.url.startswith(url.format(year, month, day)):
            continue
        page = response.content
        soup = BeautifulSoup(page, 'html.parser')
        articles = soup.find_all("div", class_="postArticle postArticle--short js-postArticle js-trackPostPresentation js-trackPostScrolls")
        for article in articles:
            title = article.find("h3", class_="graf--title")
            if title is None:
                continue
            title = title.contents[0]
            article_id += 1
            subtitle = article.find("h4", class_="graf--subtitle")
            subtitle = subtitle.contents[0] if subtitle is not None else ''
            image = article.find("img", class_="graf-image")
            image = '' if image is None else get_img(image['src'], 'images', f'{article_id}')
            article_url = article.find_all("a")[3]['href'].split('?')[0]
            claps = get_claps(article.find_all("button")[1].contents[0])
            reading_time = article.find("span", class_="readingTime")
            reading_time = 0 if reading_time is None else int(reading_time['title'].split(' ')[0])
            responses = article.find_all("a")
            if len(responses) == 7:
                responses = responses[6].contents[0].split(' ')
                if len(responses) == 0:
                    responses = 0
                else:
                    responses = responses[0]
            else:
                responses = 0

            data.append([article_id, article_url, title, subtitle, image, claps, responses, reading_time, publication, date])
# Out:
# 1 / 50 ; 2019-02-28
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [41], in <cell line: 5>()
#      26 image = '' if image is None else get_img(image['src'], 'images', f'{article_id}')
#      27 article_url = article.find_all("a")[3]['href'].split('?')[0]
# ---> 28 claps = get_claps(article.find_all("button")[1].contents[0])
#      29 reading_time = article.find("span", class_="readingTime")
#      30 reading_time = 0 if reading_time is None else int(reading_time['title'].split(' ')[0])
#
# IndexError: list index out of range

# %%
medium_df = pd.DataFrame(data, columns=['id', 'url', 'title', 'subtitle', 'image', 'claps', 'responses', 'reading_time', 'publication', 'date'])

# %%
medium_df
# Out:
#     id                                                url  \
# 0    1  https://towardsdatascience.com/the-ultimate-gu...
# 1    2  https://towardsdatascience.com/10-git-commands...
# 2    3  https://towardsdatascience.com/implementing-a-...
# 3    4  https://towardsdatascience.com/data-engineerin...
# 4    5  https://towardsdatascience.com/reinforcement-l...
# 5    6  https://towardsdatascience.com/speaker-diariza...
# 6    7  https://towardsdatascience.com/markov-chain-mo...
# 7    8  https://towardsdatascience.com/can-we-stop-wit...
# 8    9  https://towardsdatascience.com/how-to-make-you...
# 9   10  https://towardsdatascience.com/one-neural-netw...
# 10  11  https://towardsdatascience.com/machine-learnin...
# 11  12  https://towardsdatascience.com/the-python-drea...
# 12  13  https://towardsdatascience.com/ai-for-everyone...
# 13  14  https://towardsdatascience.com/artificial-inte...
# 14  15  https://towardsdatascience.com/skin-cancer-cla...
# 15  16  https://towardsdatascience.com/surprising-find...
# 16  17  https://towardsdatascience.com/generative-adve...
# 17  18  https://towardsdatascience.com/classification-...
# 18  19  https://towardsdatascience.com/conducting-a-po...
# 19  20  https://towardsdatascience.com/climate-heatmap...
# 20  21  https://towardsdatascience.com/data-analysis-o...
# 21  22  https://towardsdatascience.com/the-more-i-lear...
# 22  23  https://towardsdatascience.com/how-to-hire-and...
# 23  24  https://towardsdatascience.com/see-the-world-t...
# 24  25  https://towardsdatascience.com/supervised-mach...
# 25  26  https://uxdesign.cc/samsung-galaxy-fold-is-the...
# 26  27  https://uxdesign.cc/should-ux-desingers-learn-...
# 27  28  https://uxdesign.cc/systematic-product-design-...
# 28  29  https://uxdesign.cc/why-you-should-design-the-...
# 29  30  https://uxdesign.cc/whats-in-your-basqet-17248...
# 30  31  https://uxdesign.cc/how-i-started-in-the-ux-ui...
# 31  32  https://uxdesign.cc/designing-voice-activated-...
# 32  33  https://uxdesign.cc/games-ux-designing-for-acq...
# 33  34  https://uxdesign.cc/why-brand-personality-is-b...
# 34  35  https://uxdesign.cc/beware-creating-a-maximal-...
# 35  36  https://uxdesign.cc/finding-my-why-what-i-lear...
# 36  37  https://uxdesign.cc/3-mistakes-to-avoid-when-c...
# 37  38  https://uxdesign.cc/freelancers-screen-your-cl...
# 38  39  https://uxdesign.cc/research-helps-us-see-the-...
# 39  40  https://uxdesign.cc/the-fear-of-boredom-eca456...
# 40  41  https://uxdesign.cc/optimised-to-a-state-of-ex...
# 41  42  https://medium.com/swlh/we-are-slaves-to-money...
# 42  43  https://medium.com/swlh/suite-of-annotation-to...
# 43  44  https://medium.com/swlh/10-life-changing-lesso...
# 44  45  https://medium.com/swlh/problems-dont-exist-in...
# 45  46  https://medium.com/swlh/sorting-algorithms-imp...
# 46  47  https://medium.com/swlh/micro-investing-the-fu...
# 47  48  https://medium.com/swlh/sharkonomics-how-busin...
# 48  49  https://medium.com/swlh/on-the-analytic-the-em...
#
#                                                 title  \
# 0                 The Ultimate Guide to Data Cleaning
# 1                     10 Git Commands You Should Know
# 2   Implementing a Naive Bayes classifier for text...
# 3   Data Engineering with Python, Django, and Post...
# 4   Reinforcement Learning Tutorial Part 3: Basic ...
# 5                      Speaker Diarization with Kaldi
# 6                            Markov Chain Monte Carlo
# 7   Can we stop with the SQL JOINs venn diagrams i...
# 8          How to make your model awesome with Optuna
# 9                       One neural network, many uses
# 10                     Machine Learning for Marketers
# 11                               The Python Dreamteam
# 12  AI For Everyone: What Andrew Ng wants to conve...
# 13  Artificial Intelligence can never be truly int...
# 14   Skin cancer classification with machine learning
# 15     Surprising Findings in Document Classification
# 16  Generative Adversarial Networks: Revitalizing ...
# 17  Classification Algorithm Using Probability Pat...
# 18  [Conducting a Population Proportion Estimation...
# 19                         Climate Heatmaps Made Easy
# 20  Data Analysis Shows Regional Healthcare Costs ...
# 21  The more I learn about data, the more people i...
# 22  How to hire and build a software development t...
# 23              See the world through numbered colour
# 24                        Supervised Machine Learning
# 25       Samsung Galaxy Fold is the Homer Simpson car
# 26  Should UX designers learn to code? An ex-devel...
# 27             Systematic product design for startups
# 28  Why you should design the content first for be...
# 29           What’s in your Basqet? — a UX case study
# 30                 How I started in the UX & UI world
# 31  Designing voice-activated learning management ...
# 32                Games UX: designing for acquisition
# 33  Why brand personality is better for business t...
# 34        MVP doesn’t mean Maximal Voluminous Product
# 35  Finding my why: what I learnt from working on ...
# 36  3 mistakes to avoid when creating paper protot...
# 37  Freelancers, screen your clients before taking...
# 38  Research helps us see the human face, not just...
# 39                                The fear of boredom
# 40                 Optimised to a state of exhaustion
# 41             We Are Slaves To Money And Then We Die
# 42      Suite of Annotation Tools for Computer Vision
# 43  10 Life-Changing Lessons From Arnold Schwarzen...
# 44                Problems don’t exist in the present
# 45  Sorting Algorithms: Implementing Insertion Sor...
# 46            Micro-investing, the future of finance?
# 47  Sharkonomics — How Business Angels Evaluate Pi...
# 48        On the Analytic, the Emergent, and Avocados
#
#                                              subtitle    image  claps  \
# 0                    When the data is spewing garbage    1.png   3100
# 1                     Plus tips to save time with Git   2.jpeg   6600
# 2                         The Naive Bayes classifier…    3.png    243
# 3                                                       4.jpeg    389
# 4                                                       5.jpeg    344
# 5   the ability to process audio of multiple speak...    6.jpg    640
# 6   Lifting your understanding of MCMC to an inter...    7.png    390
# 7                                                        8.png   1000
# 8   Easily and efficiently optimize model’s hyperp...   9.jpeg    435
# 9   Build image search, image captioning, similar ...  10.jpeg   1800
# 10  In this article, we will outline how marketers...   11.png    150
# 11  As a Data Scientist, I code almost entirely in...   12.png    564
# 12                                                     13.jpeg    415
# 13        Let’s say I’m locked in a room and given a…  14.jpeg    430
# 14                                                     15.jpeg    235
# 15                          Sometimes Simplicity Wins  16.jpeg    159
# 16                                                      17.gif    142
# 17      A classification algorithm using probability…  18.jpeg     69
# 18                                                     19.jpeg      5
# 19  Investigating Paleoclimate Data with Pandas an...   20.png    108
# 20                                                     21.jpeg     28
# 21         How I left a full-time job to pursue Data…   22.jpg     24
# 22                                                      23.jpg      3
# 23  Interactive Choropleth Map of Hong Kong 2016 P...   24.png    103
# 24  Before we start this article about Supervised ...              47
# 25  Good product design is not about letting your ...  26.jpeg   1800
# 26                    Let’s reframe this question to…   27.jpg    515
# 27                                                     28.jpeg    625
# 28                                                     29.jpeg    715
# 29        The UX/UI Journey of a Regional Supermarket  30.jpeg    418
# 30                                                      31.jpg    186
# 31                                                     32.jpeg    187
# 32                                                      33.png     87
# 33                 [Deja vu! It feels like I’ve seen]   34.png     78
# 34  A maximal voluminous product is a focus on vol...   35.png    118
# 35                                                      36.gif    676
# 36  Paper prototypes are lo-fi prototypes that can...   37.jpg     20
# 37                         A screening framework for…  38.jpeg    538
# 38                A few guidelines for UX and Design…  39.jpeg     17
# 39                                                      40.gif     12
# 40                                                      41.gif     24
# 41                But it doesn’t have to be that way.  42.jpeg    532
# 42  Our suite of annotation tools to generate trai...  43.jpeg    194
# 43      Your path to stardom starts from your mindset   44.jpg    107
# 44              “… so why not spend more time there.”  45.jpeg   1100
# 45                                                      46.png    235
# 46                                                     47.jpeg    283
# 47                                                     48.jpeg     37
# 48  Escaping Our Epistemic Path-Dependence, From t...  49.jpeg     65
#
#    responses  reading_time           publication        date
# 0         10            15  Towards Data Science  2019-02-28
# 1          6             6  Towards Data Science  2019-02-28
# 2          2             8  Towards Data Science  2019-02-28
# 3          2            10  Towards Data Science  2019-02-28
# 4          6             5  Towards Data Science  2019-02-28
# 5          9             8  Towards Data Science  2019-02-28
# 6          2             5  Towards Data Science  2019-02-28
# 7         12             5  Towards Data Science  2019-02-28
# 8          4             5  Towards Data Science  2019-02-28
# 9          7            15  Towards Data Science  2019-02-28
# 10         4             4  Towards Data Science  2019-02-28
# 11         4             4  Towards Data Science  2019-02-28
# 12         3             5  Towards Data Science  2019-02-28
# 13         4             7  Towards Data Science  2019-02-28
# 14         1            11  Towards Data Science  2019-02-28
# 15         0             4  Towards Data Science  2019-02-28
# 16         2             6  Towards Data Science  2019-02-28
# 17         1             8  Towards Data Science  2019-02-28
# 18         0             6  Towards Data Science  2019-02-28
# 19         0             5  Towards Data Science  2019-02-28
# 20         0            14  Towards Data Science  2019-02-28
# 21         0             8  Towards Data Science  2019-02-28
# 22         0             6  Towards Data Science  2019-02-28
# 23         0             4  Towards Data Science  2019-02-28
# 24         0             3  Towards Data Science  2019-02-28
# 25        11             5         UX Collective  2019-02-28
# 26         3             7         UX Collective  2019-02-28
# 27         0            11         UX Collective  2019-02-28
# 28         1             4         UX Collective  2019-02-28
# 29         1            10         UX Collective  2019-02-28
# 30         0             6         UX Collective  2019-02-28
# 31         0             9         UX Collective  2019-02-28
# 32         2             6         UX Collective  2019-02-28
# 33         0            20         UX Collective  2019-02-28
# 34         1             7         UX Collective  2019-02-28
# 35         0             5         UX Collective  2019-02-28
# 36         0             2         UX Collective  2019-02-28
# 37         1             4         UX Collective  2019-02-28
# 38         0             5         UX Collective  2019-02-28
# 39         0             2         UX Collective  2019-02-28
# 40         0             2         UX Collective  2019-02-28
# 41         5             7           The Startup  2019-02-28
# 42         0             9           The Startup  2019-02-28
# 43         1             6           The Startup  2019-02-28
# 44         6             4           The Startup  2019-02-28
# 45         1             4           The Startup  2019-02-28
# 46         5             5           The Startup  2019-02-28
# 47         0             7           The Startup  2019-02-28
# 48         3            11           The Startup  2019-02-28

# %%
medium_df.to_csv('medium_data.csv', index=False)
